# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.plot([0,0,1,1], [1,0,1,0], 'ro')
plt.axis([-1, 2, -1, 2])
plt.show()

# %%
import numpy as np

[0,1/2] 
[1/2, 0]

plt.plot([0,0,1,1], [1,0,1,0], 'ro')
plt.plot([0,1/2], [1/2,0])

plt.axis([-1, 2, -1, 2])
plt.show()
